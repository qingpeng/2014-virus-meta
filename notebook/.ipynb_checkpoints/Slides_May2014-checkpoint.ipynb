# %% [markdown]
# - presented on May 14
# - modified on June 20

# %%
import pandas as pd
import numpy as np
import scipy
from IPython.display import HTML
from scipy.cluster.hierarchy import linkage, dendrogram
from scipy.spatial.distance import pdist, squareform
from IPython.display import Image

# %%
def draw_den(matrix,linkage_method,label,title):
    dendrogram(linkage(matrix, method=linkage_method), leaf_font_size=13,labels=label, leaf_rotation=90)
    plt.xlabel('points')
    plt.ylabel('Height')
    plt.title(title, fontweight='bold', fontsize=20)

# %% [markdown]
# # Compare metagenomic samples using reads coverage

# %% [markdown]
# - Method
#     - Median k-mer frequency of a read can represent reads coverage(sequencing depth)
#     - similarity matrix and clustering
# - Test data sets
#     - Sorcerer II Global Ocean Sampling Expedition
#     - MetHit Human Gut metagenomics data set
# - Using method on Ballast water viromes of great lakes system
# - Let's go bigger: GPGC Great Prairie Soil samples

# %% [markdown]
# ## Method

# %% [markdown]
# ### Median k-mer frequency of a read can represent reads coverage(sequencing depth)

# %%
Image(filename="diginorm-ranks.png")

# %% [raw]
# Representative rank-abundance distributions for 20-mers from 100-base reads with no errors, a read with a single substitution error, and a read with multiple substitution errors.
# (Brown et al., 2012)

# %% [markdown]
# ### similarity matrix and clustering

# %% [markdown]
# Coverage of a read in different samples
#
# If the median k-mer frequency of a read in a sample is >=1, we consider this read as being covered by that sample.
#
# More stringent in Compareads(Maillet et al. 2012): Given integers k and t, two sequences s1 and s2 are said similar if and only if they share at least t non-overlapping k-mers.

# %%
# !more AB.tr.fq.trimmed.fq.comb.head.txt
# Out:
# =HWI-ST957:262:H7B0HADXX:2:1101:2010:2056/1 30674 590 650 1009 714 551 12 114
# HWI-ST957:262:H7B0HADXX:2:1101:2010:2056/2 65535 872 757 901 65535 797 1068 863
# HWI-ST957:262:H7B0HADXX:2:1101:4103:2117/1 1 0 0 0 0 0 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:4103:2117/2 1 0 0 0 0 0 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:5460:2076/1 1 0 0 0 0 0 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:5460:2076/2 1 0 0 0 0 0 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:6043:2199/1 17 0 0 0 0 0 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:6043:2199/2 18 0 0 0 0 7 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:6849:2118/2 21 0 0 0 0 0 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:8384:2137/1 8 12 0 11 0 19 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:8748:2195/1 4 0 0 0 0 0 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:8748:2195/2 3 0 0 0 0 0 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:8955:2171/1 6 1 0 0 0 0 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:10116:2135/1 1 0 0 0 0 0 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:10116:2135/2 1 0 0 0 0 0 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:11381:2150/1 17 1 0 28 0 0 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:11381:2150/2 2 0 0 0 0 0 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:12658:2122/1 3 0 0 0 0 4 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:12658:2122/2 44 0 0 0 0 8 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:14126:2113/1 1 0 0 0 0 0 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:14126:2113/2 2 0 0 0 0 0 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:14411:2161/1 2 0 0 0 0 0 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:14411:2161/2 2 0 0 0 0 0 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:14926:2102/1 1 0 0 0 0 0 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:14926:2102/2 1 0 0 0 0 0 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:15087:2034/1 0 0 0 0 0 1 0 7
# HWI-ST957:262:H7B0HADXX:2:1101:15087:2034/2 1 0 0 0 0 1 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:16658:2240/1 397 19 5 25 7 6 0 1
# HWI-ST957:262:H7B0HADXX:2:1101:16658:2240/2 182 23 7 98 14 5 0 1
# HWI-ST957:262:H7B0HADXX:2:1101:17017:2234/1 2 0 0 0 0 0 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:17017:2234/2 2 0 0 0 0 0 0 0
# HWI-ST957:262:H7B0HADXX:2:1101:17804:2212/1 704 0 0 4 1 1 0 1
# HWI-ST957:262:H7B0HADXX:2:1101:17804:2212/2 682 0 0 0 1 1 0 1
# HWI-ST957:262:H7B0HADXX:2:1101:18620:2059/1 1 0 0 0 0 0 0 0
# >

# %% [markdown]
# ### Distance

# %% [markdown]
# - AinB: number of reads in sample A that are covered in sample B
# - BinA: number of reads in sample B that are covered in sample A
# - A: number of reads in sample A
# - B: number of reads in sample B
#
# distance = (AinB+BinA)/(A+B)

# %% [markdown]
# Clustering(Linkage):
# - Complete
# - Average

# %% [markdown]
# ## Test: Sorcerer II Global Ocean Sampling Expedition

# %% [markdown]
# － http://www.plosbiology.org/article/info%3Adoi%2F10.1371%2Fjournal.pbio.0050077
# - 2007
# - 454 sequencing, longer reads
# - use 44 samples in testing

# %%
GOS=pd.read_csv('../data/GOS_distance.txt',delimiter=' ',header=None)
label=pd.read_csv('../data/config-GOS.txt',delimiter='  ',header=None)
samples = label[:1]
new = []
#print samples.values[0]
for sample in samples.values[0]:
        #print str(sample)
        new.append(str(sample).split('.')[0])
GOS=GOS.ix[:,3:46] 
GOS.columns=new
GOS.index=new

# %%
GOS
# Out:
#           GS000a    GS000b    GS000c    GS000d    GS001a    GS001b    GS001c  \
# GS000a  0.997792  0.102807  0.106175  0.111934  0.015684  0.020614  0.049150
# GS000b  0.102807  1.000000  0.209925  0.225664  0.018092  0.024593  0.088885
# GS000c  0.106175  0.209925  1.000000  0.196210  0.010448  0.007998  0.037846
# GS000d  0.111934  0.225664  0.196210  1.000000  0.016562  0.028775  0.086481
# GS028   0.005802  0.015900  0.004156  0.001202  0.006005  0.067384 ...
# GS029   0.004212  0.011971  0.003293  0.001110  0.003969  0.066506 ...
# GS030   0.006140  0.013256  0.003987  0.002466  0.006400  0.092499 ...
# GS031   0.006539  0.012221  0.003743  0.001346  0.006199  0.041936 ...
# GS032   0.009770  0.014024  0.004203  0.003177  0.008778  0.016183 ...
# GS033   0.000213  0.000191  0.000296  0.000279  0.000726  0.000275 ...
# GS034   0.003393  0.010647  0.002736  0.000898  0.003558  0.071473 ...
# GS035   0.003557  0.008799  0.002149  0.000790  0.003590  0.036255 ...
# GS036   0.004042  0.013828  0.003401  0.000943  0.004472  0.062178 ...
# GS037   0.001642  0.003313  0.001289  0.000725  0.001645  0.015461 ...
# GS047   0.001631  0.002848  0.001402  0.000947  0.001397  0.013509 ...
# GS051   0.002909  0.013566  0.003986  0.001141  0.003974  0.102627 ...
#
# [44 rows x 44 columns]

# %% [markdown]
# ### linkage method: complete

# %%
figure(num=None, figsize=(12, 12))
R = dendrogram(linkage(GOS, method='complete'),labels=new, leaf_font_size=2,orientation='right')

ylabel('points')
xlabel('Height')
xlim(1,1.6)
suptitle('GOS, complete', fontweight='bold', fontsize=20)

# %% [markdown]
# ### linkage method: average

# %%
figure(num=None, figsize=(12, 12))
R = dendrogram(linkage(GOS, method='average'),labels=new, leaf_font_size=20,orientation='right')

ylabel('points')
xlabel('Height')
xlim(1,1.6)
suptitle('GOS: average', fontweight='bold', fontsize=20)

# %%
def heatmap(tb):
    from scipy.cluster.hierarchy import linkage, dendrogram
    from scipy.spatial.distance import pdist, squareform
    

    f = figure(figsize=(15, 15))
    D=tb.ix[tb.index[::-1],:]
    #print D
    D=D.ix[:,tb.columns[::-1]]
    #print D
#D = tb.ix[idx1, :]
    #print D
#D = D.ix[:, idx2]
    # add first dendrogram
    #ax1 = f.add_axes([0.09, 0.1, 0.2, 0.6])
    #Y = linkage(D, method='average')
    #Z1 = dendrogram(Y, orientation='right',labels=col)
    #ax1.set_xticks([])
    #ax1.set_yticks([])

    # add second dendrogram
    ax2 = f.add_axes([0.3, 0.71, 0.6, 0.2])
    Y = linkage(tb, method='average')
    Z2 = dendrogram(Y)
    ax2.set_xticks([])
    ax2.set_yticks([])
    #ylim(1,1.6)

    # add matrix plot
    axmatrix = f.add_axes([0.3, 0.1, 0.6, 0.6])
    idx1 = Z2['leaves']
    #print idx1
    
    idx2 = Z2['leaves']
    #print idx2
    #print tb
    ri =  idx1[::-1]
    #print ri
    D = tb.ix[idx1, :]
    #print D
    D = D.ix[:, idx2]
    #print D
    im = axmatrix.matshow(D, aspect='auto', cmap='gist_yarg')#, origin='lower'
    #axmatrix.set_xticks(col)
    
    #axmatrix.set_yticks(col)
    #print D.index[Z2['leaves']]
    axmatrix.set_yticks(arange(D.shape[0]))
    axmatrix.yaxis.set_ticks_position('right')
    
    axmatrix.set_yticklabels(tb.index[Z2['leaves']])

## col labels ##
    axmatrix.set_xticks(arange(D.shape[1]))
    axmatrix.xaxis.set_ticks_position('bottom')
    xlabelsL = axmatrix.set_xticklabels(tb.columns[Z2['leaves']])
# rotate labels 90 degrees
    for label in xlabelsL:
        label.set_rotation(90)
# remove the tick lines
    for l in axmatrix.get_xticklines() + axmatrix.get_yticklines(): 
        l.set_markersize(0)
    
    
    return 0

# %%
heatmap(GOS)
# Out:
# 0

# %% [markdown]
# #### Compareads paper

# %%
Image(filename="comp.png")

# %% [markdown]
# #### original paper

# %%
Image(filename="GOS1.png")

# %% [markdown]
# ### Discussion of GOS data test

# %% [markdown]
# - got similar result as Compareads, and original paper
# - try to find any significant difference, since our method is different.(less strigent but should make more sense. - graph coverage vs. read to read comparison...)

# %% [markdown]
# ## MetHit Human Gut metagenomics data set

# %% [markdown]
# － http://www.nature.com/nature/journal/v464/n7285/full/nature08821.html
# - 2010
# - Illumina reads, shorter
# - 570GB
# - 124 European adults, here picked 39 samples, 25 with Inflammatory bowel disease (IBD)

# %%
Image(filename="methit.png")

# %%
MH=pd.read_csv('../data/MH_distance.txt',delimiter=',',index_col=0)

# %%
MH
# Out:
#           O2.UC-11  O2.UC-12  O2.UC-13  O2.UC-14  O2.UC-16  O2.UC-17  \
# O2.UC-11  1.000000  0.838556  0.594748  0.775327  0.817898  0.825411
# O2.UC-12  0.838556  1.000000  0.820822  0.806529  0.786562  0.764637
# O2.UC-13  0.594748  0.820822  1.000000  0.838945  0.881323  0.827209
# O2.UC-14  0.775327  0.806529  0.838945  1.000000  0.736016  0.674180
# O2.UC-16  0.817898  0.786562  0.881323  0.736016  1.000000  0.689002
# O2.UC-17  0.825411  0.764637  0.827209  0.674180  0.689002  1.000000
# O2.UC-18  0.867338  0.856449  0.903426  0.883024  0.923105  0.882702
# O2.UC-19  0.696861  0.736135  0.773768  0.817014  0.870352  0.815959
# O2.UC-1   0.801050  0.726198  0.815671  0.734013  0.683679  0.659469
# O2.UC-20  0.642457  0.739962  0.709912  0.755449  0.845911  0.776379
# O2.UC-21  0.857094  0.969804  0.929809  0.946272  0.926725  0.951574
# O2.UC-22  0.671498  0.777794  0.736623  0.726164  0.878326  0.769310
# O2.UC-23  0.782935  0.735558  0.733278  0.797906  0.872368  0.792675
# O2.UC-24  0.715229  0.709863  0.839527  0.711602  0.687968  0.636124
# O2.UC-4   0.716762  0.916619  0.822833  0.863144  0.929879  0.906564
# V1.CD-11  0.852368  0.912139  0.837312  0.842765  0.925037  0.849736
# V1.CD-12  0.908811  0.885879  0.863806  0.791330  0.945557  0.838536
# V1.CD-13  0.624146  0.724865  0.745812  0.787682  0.852177  0.825463
# V1.CD-14  0.754319  0.745378  0.728233  0.747508  0.892197  0.778790
# V1.CD-15  0.550780  0.741186  0.608892  0.666429  0.893885  0.625532
# V1.CD-1   0.893829  0.869118  0.810544  0.795979  0.921063  0.782899
# V1.CD-2   0.900912  0.879621  0.900259  0.769707  0.705433  0.618591
# V1.CD-3   0.729255  0.889562  0.768341  0.840348  0.908821  0.841664
# V1.CD-4   0.766251  0.835559  0.768767  0.769818  0.887064  0.858263
# V1.CD-6   0.826551  0.813383  0.750604  0.754602  0.890158  0.760778
    #print count
    if count%6 == 1:
        sample = line
        labels[sample]=line
    else:
        labels[sample] = labels[sample]+'>'+line
    count = count+1
#print labels

label = MH.columns
label
L = []
for l in label:
    L.append(labels[l])

# %%
figure(num=None, figsize=(12, 12))
R = dendrogram(linkage(MH, method='average'), leaf_font_size=13,labels=L, leaf_rotation=90,orientation='right')

ylabel('points')
xlabel('Height')
#ylim(1,1.6)
suptitle('MetHit, complete', fontweight='bold', fontsize=20)
savefig('MH.pdf')

# %%
figure(num=None, figsize=(12, 12))
R = dendrogram(linkage(MH, method='complete'), leaf_font_size=13,labels=L, leaf_rotation=90,orientation='right')

ylabel('points')
xlabel('Height')
#ylim(1,1.6)
suptitle('MetHit, average', fontweight='bold', fontsize=20)
savefig('MH.pdf')

# %% [markdown]
# ### Discussion of MetHit data test

# %% [markdown]
# - can not differentiate patients and healthy people
# - need to make sense of the cluster

# %% [markdown]
# ## Using method on Ballast water viromes of great lakes system

# %%
tb=pd.read_csv('../data/distance.txt',index_col=0)
tb
# Out:
#           AB        BH        IH        MH        BB        IB        MB  \
# AB  0.999273  0.456992  0.369753  0.467563  0.541378  0.386002  0.712956
# BH  0.456992  0.997706  0.328564  0.487880  0.572596  0.317692  0.773194
# IH  0.369753  0.328564  0.994605  0.426303  0.480611  0.208128  0.753221
# MH  0.467563  0.487880  0.426303  0.998566  0.572498  0.401382  0.703367
# BB  0.541378  0.572596  0.480611  0.572498  0.998295  0.478255  0.859050
# IB  0.386002  0.317692  0.208128  0.401382  0.478255  0.997764  0.692968
# MB  0.712956  0.773194  0.753221  0.703367  0.859050  0.692968  0.999906
# PB  0.405991  0.374767  0.252138  0.434187  0.551685  0.404171  0.751274
#
#           PB
# AB  0.405991
# BH  0.374767
# IH  0.252138
# MH  0.434187
# BB  0.551685
# IB  0.404171
# MB  0.751274
# PB  0.998362
#
# [8 rows x 8 columns]

# %%
col = list(tb.columns.values)

# %%
R = dendrogram(linkage(tb, method='complete'),labels=col)

xlabel('points')
ylabel('Height')
suptitle('Virus, complete', fontweight='bold', fontsize=14);

# %%
R = dendrogram(linkage(tb, method='average'),labels=col)

xlabel('points')
ylabel('Height')
suptitle('Virus, average', fontweight='bold', fontsize=14);

# %%
heatmap(tb)
# Out:
# 0

# %% [markdown]
# ### digital normalization --> 5x coverage.

# %% [markdown]
# - The purpose is to decrease the influence of uneven species abundance distribution.
# - Previous comparison is the comparison of genomic contents -- including everything, all the DNAs in samples that are sequenced,  with high abundance or low abundance.
# - This comparison is close to the comparison on species level without the influence of species abundance.
# - Now the abundance/coverage is in the range of 1 to 5.

# %% [markdown]
# ### The distance matrix after diginormed.

# %%
DV=pd.read_csv('../data/digi_virus_distance.txt',delimiter=',',index_col=0)
DV
# Out:
#           AB        BH        IH        MH        BB        IB        MB  \
# AB  0.996222  0.088069  0.075315  0.084753  0.083046  0.042898  0.099280
# BH  0.088069  0.091650  0.522037  0.073322  0.438948  0.048193  0.104190
# IH  0.075315  0.522037  0.059073  0.068695  0.642799  0.034182  0.063716
# MH  0.084753  0.073322  0.068695  0.063801  0.098434  0.598251  0.867653
# BB  0.083046  0.438948  0.642799  0.098434  0.067407  0.040944  0.085854
# IB  0.042898  0.048193  0.034182  0.598251  0.040944  0.021330  0.142615
# MB  0.099280  0.104190  0.063716  0.867653  0.085854  0.142615  0.126049
# PB  0.063201  0.077011  0.040707  0.101094  0.084197  0.077577  0.082278
#
#           PB
# AB  0.063201
# BH  0.077011
# IH  0.040707
# MH  0.101094
# BB  0.084197
# IB  0.077577
# MB  0.082278
# PB  0.994577
#
# [8 rows x 8 columns]

# %% [markdown]
# The distance matrix before diginormed. lots of difference now. MB and MH are closer on species level??

# %%
tb
# Out:
#           AB        BH        IH        MH        BB        IB        MB  \
# AB  0.999273  0.456992  0.369753  0.467563  0.541378  0.386002  0.712956
# BH  0.456992  0.997706  0.328564  0.487880  0.572596  0.317692  0.773194
# IH  0.369753  0.328564  0.994605  0.426303  0.480611  0.208128  0.753221
# MH  0.467563  0.487880  0.426303  0.998566  0.572498  0.401382  0.703367
# BB  0.541378  0.572596  0.480611  0.572498  0.998295  0.478255  0.859050
# IB  0.386002  0.317692  0.208128  0.401382  0.478255  0.997764  0.692968
# MB  0.712956  0.773194  0.753221  0.703367  0.859050  0.692968  0.999906
# PB  0.405991  0.374767  0.252138  0.434187  0.551685  0.404171  0.751274
#
#           PB
# AB  0.405991
# BH  0.374767
# IH  0.252138
# MH  0.434187
# BB  0.551685
# IB  0.404171
# MB  0.751274
# PB  0.998362
#
# [8 rows x 8 columns]

# %%
R = dendrogram(linkage(DV, method='average'),labels=col)

xlabel('points')
ylabel('Height')
suptitle('Virus, diginorm -> 5x, average', fontweight='bold', fontsize=14);

# %% [markdown]
# #### Compared to original data:

# %%
R = dendrogram(linkage(tb, method='average'),labels=col)

xlabel('points')
ylabel('Height')
suptitle('Virus, average', fontweight='bold', fontsize=14);

# %%
R = dendrogram(linkage(DV, method='complete'),labels=col)

xlabel('points')
ylabel('Height')
suptitle('Virus, diginorm -> 5x, complete', fontweight='bold', fontsize=14);

# %%
R = dendrogram(linkage(tb, method='complete'),labels=col)

xlabel('points')
ylabel('Height')
suptitle('Virus,  complete', fontweight='bold', fontsize=14);

# %% [markdown]
# ### Discussion about virus data set

# %% [markdown]
# - Different linkage methods got different cluster, (average vs complete)
# - "kind of " like Yiseul's PCA figure
#     - should not be surprised. assembly based, by tBlastx and Nucmer

# %%
#Image(filename="y1.png")
y1 = Image(filename="y1.png")
y2 = Image(filename="y2.png")
display(y1, y2)

# %% [markdown]
# ## Let's go bigger: GPGC Great Prairie Soil samples

# %% [markdown]
# - 8 samples
# - 1.4T raw fastq gz data

# %%
GPGC=pd.read_csv('../data/GPGC_distance.txt',delimiter=',',index_col=0)

L=GPGC.index
GPGC
# Out:
#                        iowa_corn  iowa_prairie  kansas_corn  kansas_prairie  \
# iowa_corn               1.000000      0.448079     0.322844        0.280775
# iowa_prairie            0.448079      1.000000     0.416062        0.353398
# kansas_corn             0.322844      0.416062     1.000000        0.210861
# kansas_prairie          0.280775      0.353398     0.210861        1.000000
# wisconsin_corn          0.265899      0.414659     0.232124        0.201380
# wisconsin_prairie       0.384843      0.561744     0.376802        0.291818
# wisconsin_restored      0.570696      0.671833     0.622372        0.589575
# wisconsin_switchgrass   0.500718      0.626137     0.538749        0.537770
#
#                        wisconsin_corn  wisconsin_prairie  wisconsin_restored  \
# iowa_corn                    0.265899           0.384843            0.570696
# iowa_prairie                 0.414659           0.561744            0.671833
# kansas_corn                  0.232124           0.376802            0.622372
# kansas_prairie               0.201380           0.291818            0.589575
# wisconsin_corn               1.000000           0.316388            0.421595
# wisconsin_prairie            0.316388           1.000000            0.613239
# wisconsin_restored           0.421595           0.613239            1.000000
# wisconsin_switchgrass        0.338335           0.579780            0.425643
#
#                        wisconsin_switchgrass
# iowa_corn                           0.500718
# iowa_prairie                        0.626137
# kansas_corn                         0.538749
# kansas_prairie                      0.537770
# wisconsin_corn                      0.338335
# wisconsin_prairie                   0.579780
# wisconsin_restored                  0.425643
# wisconsin_switchgrass               1.000000
#
# [8 rows x 8 columns]

# %%
GPGC5X=pd.read_csv('../data/GPGC_distance_5X.txt',delimiter=',',index_col=0)

L5X=GPGC5X.index
GPGC5X
# Out:
#                        iowa_corn  iowa_prairie  kansas_corn  kansas_prairie  \
# iowa_corn               1.000000      0.319450     0.290538        0.215784
# iowa_prairie            0.319450      1.000000     0.324903        0.241976
# kansas_corn             0.290538      0.324903     1.000000        0.166620
# kansas_prairie          0.215784      0.241976     0.166620        1.000000
# wisconsin_corn          0.245625      0.305057     0.235033        0.159893
# wisconsin_prairie       0.292319      0.345427     0.317647        0.211298
# wisconsin_restored      0.406101      0.433944     0.520373        0.374921
# wisconsin_switchgrass   0.371619      0.418432     0.465055        0.351690
#
#                        wisconsin_corn  wisconsin_prairie  wisconsin_restored  \
# iowa_corn                    0.245625           0.292319            0.406101
# iowa_prairie                 0.305057           0.345427            0.433944
# kansas_corn                  0.235033           0.317647            0.520373
# kansas_prairie               0.159893           0.211298            0.374921
# wisconsin_corn               1.000000           0.275574            0.399864
# wisconsin_prairie            0.275574           1.000000            0.445730
# wisconsin_restored           0.399864           0.445730            1.000000
# wisconsin_switchgrass        0.332117           0.430340            0.425679
#
#                        wisconsin_switchgrass
# iowa_corn                           0.371619
# iowa_prairie                        0.418432
# kansas_corn                         0.465055
# kansas_prairie                      0.351690
# wisconsin_corn                      0.332117
# wisconsin_prairie                   0.430340
# wisconsin_restored                  0.425679
# wisconsin_switchgrass               1.000000
#
# [8 rows x 8 columns]

# %%
plt.figure(4, figsize=(12,12))

plt.subplot(2,2,1)
draw_den(GPGC,'average',L,'GPGC, average')   
plt.subplot(2,2,2)
draw_den(GPGC,'complete',L,'GPGC, complete') 

plt.subplot(2,2,3)
draw_den(GPGC5X,'average',L5X,'GPGC diginorm->5X, average') 
plt.subplot(2,2,4)
draw_den(GPGC5X,'complete',L5X,'GPGPGC diginorm->5XGC5X, complete') 

plt.tight_layout()

# %% [markdown]
# ### Discussion of GPGC data

# %% [markdown]
# - prairie/restored are grouped closer compared to corn, except kansas_prairie...
# - need diginorm --> ?

# %% [markdown]
# ## Final thoughts
